# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Admin\\weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.size
# Out:
# 24

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Group data using custom function:let's say you want to group yuor data using custom function.here the requirement is to create three groups
#     1.Days when temperature was between 80 and 90
#     2.Days when it was between 50 and 60
#     3.

# %%
df = pd.read_csv("C:\\Users\\Admin\\Desktop\\weather_by_cities.csv")
df
# Out:
#            day      city  temperature  windspeed   event
# 0   01-01-2017  new york           32          6    Rain
# 1   01-02-2017  new york           36          7   Sunny
# 2   01-03-2017  new york           28         12    Snow
# 3   01-04-2017  new york           33          7   Sunny
# 4   01-01-2017    mumbai           90          5   Sunny
# 5   01-02-2017    mumbai           85         12     Fog
# 6   01-03-2017    mumbai           87         15     Fog
# 7   01-04-2017    mumbai           92          5    Rain
# 8   01-01-2017     paris           45         20   Sunny
# 9   01-02-2017     paris           50         13  Cloudy
# 10  01-03-2017     paris           54          8  Cloudy
# 11  01-04-2017     paris           42         10  Cloudy

# %%
def groupper(weather_by_city,idx,col):
    if 80<=weather_by_city[col].loc[idx]<=90:
        return "80-90"
    elif 50<=weather_by_city[col].loc[idx]<=60:
        return "50-60"
    else:
        return "other"

# %%
for key ,d in g:
    print("\n")
    print("Group by key : {}")
    print

# %%
import numpy as np
import pandas as pd

# %%
imdb_df = pd.read_csv("imdb_data.csv")
imdb_df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
english_movies = imdb_df[imdb_df['original_language']== 'en']
long_movies = imdb_df.loc[imdb_df['runtime']>=100,['imdb_id','original_language']]

# %%
english_movies.shape
# Out:
# (2575, 23)

# %%
long_movies.shape
# Out:
# (1820, 2)

# %%
merged_0J_df=pd.merge(english_movies[['imdb_id','runtime']],long_movies,on='imdb_id',how='outer')

# %%
merged_0J_df
# Out:
#         imdb_id  runtime original_language
# 0     tt2637294     93.0               NaN
# 1     tt0368933    113.0                en
# 2     tt2582802    105.0                en
# 3     tt0093743     83.0               NaN
# 4     tt0431021     92.0               NaN
# ...         ...      ...               ...
# 2862  tt2106741      NaN                zh
# 2863  tt1093370      NaN                hi
# 2864  tt1194664      NaN                ja
# 2865  tt5320514      NaN                ml
# 2866  tt2364975      NaN                sv
#
# [2867 rows x 3 columns]

# %%
from datetime import datetime
from datetime import date

# %%
def parse_string_to_date(datestring):
    return convert_to_year(datestring)
